# %% [markdown]
# # Classification

# %% [markdown]
# ### Preprocessing

# %%
import pandas as pd

df = pd.read_csv('movie_dataset_classification.csv',index_col=0)
df.dropna(subset=['Plot'], inplace=True)
df.drop_duplicates(subset=['Title','Plot'], inplace=True)
#removing low frequency genres
counts = df.Genre.value_counts()
counts = list(counts[counts < 150].index)
df = df[~df['Genre'].isin(counts)]
df.tail(60)
# Out:
#        Release Year                             Title  \
# 40047        2010.0            The Hammer (2010 film)
# 40048        2017.0      Poorna: Courage Has No Limit
# 40049        2000.0        MVP: Most Valuable Primate
# 40051        2000.0                 A Fighter's Blues
# 40053        2001.0  All Cheerleaders Die (2001 film)
# 40054        1930.0                        Going Wild
# 40055        1989.0                 Gleaming the Cube
# 40056        2006.0       The Prince of Tennis (film)
# 40057        2016.0    Split (2016 South Korean film)
# 40058        1996.0               Kingpin (1996 film)
# 40059        2005.0        The World's Fastest Indian
# 40061        1972.0                Kansas City Bomber
# 40062        2010.0       The King of Fighters (film)
# 40063        2017.0          Sachin: A Billion Dreams
# 40067        2002.0                 Undisputed (film)
# 40068        2016.0                    Tommy's Honour
# 40069        1929.0              The Smart Set (film)
# 40070        1969.0                    Downhill Racer
# 40071        1953.0                    The Final Test
# 40074        1990.0                      Awwal Number
# 40075        1967.0                    Banning (film)
# 40076        2007.0                   Ping Pong Playa
# 40077        1932.0               You Said a Mouthful
# 40080        1978.0                     Big Wednesday
# 40081        1949.0      It's Not Cricket (1949 film)
# 40082        1994.0                     Greedy (film)
# 40083        2009.0              Vennila Kabadi Kuzhu
# 40084        2010.0           Knucklehead (2010 film)
# 40085        1986.0                  One Crazy Summer
# 40086           NaN               A Friend to Die For
# 40087        1985.0                     Summer Rental
# 40088        2009.0                    Blood and Bone
# 40089        2004.0     Bobby Jones: Stroke of Genius
# 40090        2009.0  Bring It On: Fight to the Finish
# 40091        2006.0    A League of Ordinary Gentlemen
# 40092        2014.0                  A Grande Vitória
# 40093        2002.0                           Swimfan
# 40094        2011.0                 Gamer (2011 film)
# 40095        2016.0                       Chalk It Up
# 40097        2001.0                  Waterboys (film)
# 40098        2014.0                Break Point (film)
# 40099        1980.0                        Caddyshack
# 40100        1987.0               Surf Nazis Must Die
# 40101        2017.0   Battle of the Sexes (2017 film)
# 40102        2018.0                     Soorma (film)
# 40103        2006.0                  Ajay (2006 film)
# 40106        2008.0              Morning Light (film)
# 40107        1969.0          Once You Kiss a Stranger
# 40108        2005.0           Shooting Gallery (film)
# 40109        2004.0                   Sye (2004 film)
# 40110        1993.0                       Surf Ninjas
# 40111        1997.0               Gone Fishin' (film)
# 40112        1991.0                 Ski School (film)
# 40113        2014.0                 Jeeva (2014 film)
# 40115        2012.0                      Dhoni (film)
# 40117           NaN                  Ready Player One
# 40118        2011.0                    From the Rough
# 40119           NaN                            Brink!
# 40120        2003.0                 Open Water (film)
# 40121        2013.0              All Cheerleaders Die
#
#                                  Director  \
# 40047                         Oren Kaplan
# 40048                          Rahul Bose
# 40049                        Robert Vince
# 40051                          Daniel Lee
# 40053          Lucky McKeeChris Sivertson
# 40054                   William A. Seiter
# 40055                     Graeme Clifford
# 40056                          Yuichi Abe
# 40057                       Choi Kook-hee
# 40058       Peter Farrelly Bobby Farrelly
# 40059                     Roger Donaldson
# 40061                    Jerrold Freedman
# 40062                         Gordon Chan
# 40063                       James Erskine
# 40067                         Walter Hill
# 40068                       Jason Connery
# 40069                         Jack Conway
# 40070                     Michael Ritchie
# 40071                     Anthony Asquith
# 40074                           Dev Anand
# 40075                         Ron Winston
# 40076                          Jessica Yu
# 40077                         Lloyd Bacon
# 40080                         John Milius
# 40081                Alfred RoomeRoy Rich
# 40082                       Jonathan Lynn
# 40083                        Suseenthiran
# 40084                     Michael Watkins
# 40085                Savage Steve Holland
# 40086                   William A. Graham
# 40087                         Carl Reiner
# 40088                          Ben Ramsey
# 40089                    Rowdy Herrington
# 40090                      Bille Woodruff
# 40091  Christopher Browne and Alex Browne
# 40092                     Stefano Capuzzi
# 40093                         John Polson
# 40094                        Oleg Sentsov
# 40095                     Hisonni Johnson
# 40097                     Shinobu Yaguchi
# 40098                           Jay Karas
# 40099                        Harold Ramis
# 40100                        Peter George
# 40101        Valerie FarisJonathan Dayton
# 40102                           Shaad Ali
# 40103                        Meher Ramesh
# 40106                         Mark Monroe
# 40107                        Robert Sparr
# 40108                        Keoni Waxman
# 40109                      S.S. Rajamouli
# 40110                         Neal Israel
# 40111                    Christopher Cain
# 40112                          Damian Lee
# 40113                        Suseenthiran
# 40115                         Prakash Raj
# 40117                                 NaN
# 40118                       Pierre Bagley
# 40119                         Greg Beeman
# 40120                        Chris Kentis
# 40121          Lucky McKeeChris Sivertson
#
#                                                     Cast  \
# 40047                                ['Russell Harvard']
# 40048                                 ['Harsha Vardhan']
# 40049  ['Kevin Zegers', 'Jamie Renée Smith', 'Oliver ...
# 40051                                       ['Andy Lau']
# 40053                                                 []
# 40054  ['Joe E. Brown (comedian)', 'Ona Munson', 'Wal...
# 40055               ['Christian Slater', 'Steven Bauer']
# 40056  ['Kanata Hongo', 'Yuu Shirota', 'Hirofumi Arak...
# 40057  ['Yoo Ji-tae', 'Lee Jung-hyun', 'Lee David', '...
# 40058  ['Woody Harrelson', 'Randy Quaid', 'Vanessa An...
# 40059  ['Anthony Hopkins', 'Diane Ladd', 'Jessica Cau...
# 40061         ['Raquel Welch', 'Kevin McCarthy (actor)']
# 40062  ['Sean Faris', 'Maggie Q', 'Will Yun Lee', 'Ra...
# 40063  ['Sachin Tendulkar', 'MS Dhoni', 'Virender Seh...
# 40067  ['Wesley Snipes', 'Ving Rhames', 'Peter Falk',...
# 40068  ['Peter Mullan', 'Jack Lowden', 'Ophelia Lovib...
# 40069                                 ['William Haines']
# 40070  ['Robert Redford', 'Gene Hackman', 'Camilla Sp...
# 40071           ['Jack Warner (actor)', 'Robert Morley']
# 40074     ['Dev Anand', 'Aamir Khan', 'Aditya Pancholi']
# 40075  ['Robert Wagner', 'Anjanette Comer', 'Jill St....
# 40076  ['Khary Payton', 'Roger Fan', 'Elizabeth Sung'...
# 40077  ['Joe E. Brown', 'Ginger Rogers', 'Preston Fos...
# 40080  ['Jan-Michael Vincent', 'William Katt', 'Gary ...
# 40081  ['Basil Radford', 'Naunton Wayne', 'Susan Shaw...
# 40082  ['Michael J. Fox', 'Kirk Douglas', 'Nancy Trav...
# 40083  ['Vishnu Vishal', 'Kishore (actor, born 1974)'...
# 40084   ['Big Show', 'Mark Feuerstein', 'Dennis Farina']
# 40085  ['John Cusack', 'Demi Moore', 'Curtis Armstron...
# 40086  ['Kellie Martin', 'Tori Spelling', 'Valerie Ha...
# 40087                   ['John Candy', 'Richard Crenna']
# 40088  ['Julian Sands', 'Eamonn Walker', 'Dante Basco...
# 40089  ['Jim Caviezel', 'Claire Forlani', 'Jeremy Nor...
# 40090  ['Christina Milian', 'Rachele Brooke Smith', '...
# 40091  ['Wayne Webb', 'Pete Weber (bowler)', 'Walter ...
# 40092                    ['Caio Castro', 'Sabrina Sato']
# 40093  ['Jesse Bradford', 'Erika Christensen', 'Shiri...
# 40094                                                 []
# 40095  ['John DeLuca', 'Nikki SooHoo', 'Drew Seeley',...
# 40097  ['Satoshi Tsumabuki', 'Hiroshi Tamaki', 'Akifu...
# 40098  ['David Walton (actor)', 'Amy Smart', 'Joshua ...
# 40099  ['Chevy Chase', 'Rodney Dangerfield', 'Ted Kni...
# 40100                                                 []
# 40101  ['Emma Stone', 'Steve Carell', 'Andrea Risebor...
# 40102  ['Diljit Dosanjh', 'Taapsee Pannu', 'Angad Bedi']
# 40103  ['Puneeth Rajkumar', 'Anuradha Mehta', 'Prakas...
# 40106                                                 []
# 40107  ['Paul Burke (actor)', 'Carol Lynley', 'Martha...
# 40108  ['Freddie Prinze, Jr.', 'Ving Rhames', 'Callum...
# 40109  ['Nithiin', "Genelia D'Souza", 'Shashank (acto...
# 40110  ['Ernie Reyes Jr.', 'Rob Schneider', 'Tone Lōc...
# 40111  ['Joe Pesci', 'Danny Glover', 'Rosanna Arquett...
# 40112  ['Dean Cameron', 'Stuart Fratkin', 'Darlene Vo...
# 40113                    ['Vishnu (actor)', 'Sri Divya']
# 40115                                   ['Radhika Apte']
# 40117                                                 []
# 40118  ['Taraji P. Henson', 'Tom Felton', 'Michael Cl...
# 40119  ['Erik von Detten', 'Christina Vidal', 'Robin ...
# 40120                ['Blanchard Ryan', 'Daniel Travis']
# 40121  ['Caitlin Stasey', 'Sianoa Smit-McPhee', 'Broo...
#
#                                                     Plot  Genre
# 40047  The Hammer follows Matt Hamill, who was born d...  sport
# 40048  Poorna Malavath (Aditi Inamdar) belongs to a T...  sport
# 40049  The plot revolves around an ape playing sports...  sport
# 40051  After spending 13 years in jail for killing on...  sport
# 40053  A group of high school football players gets i...  sport
# 40054  Rollo Smith (Joe E. Brown) and his friend Jack...  sport
# 40055  Brian Kelly is an underachieving high school s...  sport
# 40056  Twelve-year-old Ryoma Echizen is a tennis prod...  sport
# 40057  A man once considered a bowling legend teams u...  sport
# 40058  Flashy young bowler Roy Munson wins the 1979 I...  sport
# 40059  In 1962, Burt Munro is a sort of folk hero in ...  sport
# 40061  The film is an inside look at the world of Rol...  sport
# 40062  The King of Fighters is a tournament held in a...  sport
# 40063  The film follow two main plots- The first show...  sport
# 40067  Undisputed heavyweight boxing champion George ...  sport
# 40068  In St Andrews, Scotland in 1866, 15-year-old T...  sport
# 40069  A self-centered polo player (Haines) has to re...  sport
# 40070  American downhill skier David Chappellet (Robe...  sport
# 40071  The film is a light drama, set around elderly ...  sport
# 40074  The story revolves around cricket where a new ...  sport
# 40075  Mike McDermot is a rising golf star on the PGA...  sport
# 40076  Christopher Wang (Wong) is a young man (25 yea...  sport
# 40077  Joe Holt works for the Armstrong Rubber Goods ...  sport
# 40080  The film tells the story of three young friend...  sport
# 40081  Major Bright and Captain Early are intelligenc...  sport
# 40082  Joe McTeague is a wealthy, wheelchair-bound sc...  sport
# 40083  The story unfolds in a remote village near Pal...  sport
# 40084  Walter Krunk is a 35-year-old orphan who has l...  sport
# 40085  Hoops McCann, a recent high school graduate, f...  sport
# 40086  In the fictional town of Santa Mira, Californi...  sport
# 40087  Overworked air traffic controller Jack Chester...  sport
# 40088  Fresh out of prison, Isaiah Bone (Michael Jai ...  sport
# 40089  In 1936, golfer Bobby Jones, while traveling t...  sport
# 40090  Lina Cruz is a tough, sharp-witted cheerleader...  sport
# 40091  The documentary follows four professional ten-...  sport
# 40092  Max Trombini had a humble and troubled childho...  sport
# 40093  Ben Cronin is a star swimmer of his high schoo...  sport
# 40094  The main character in the film is a teenager n...  sport
# 40095  Apple, a student at the prestigious Greene Uni...  sport
# 40097  Suzuki is a high-school student who aspires to...  sport
# 40098  Brash man-child Jimmy Price knows his days as ...  sport
# 40099  Danny Noonan (Michael O'Keefe) works as a cadd...  sport
# 40100  An earthquake leaves the California coastline ...  sport
# 40101  In 1970, Billie Jean King and Gladys Heldman c...  sport
# 40102  In 1994, at Shahbad Hockey Centre, a young San...  sport
# 40103  Ajay  (Puneeth Rajkumar) is so clever he keeps...  sport
# 40106  Morning Light  is a documentary that follows t...  sport
# 40107  Jerry is a professional golfer. When a woman n...  sport
# 40108  Jericho Hudson is a street smart kid with a gi...  sport
# 40109  Prudhvi (Nithiin) and Shashank (Shashank) are ...  sport
# 40110  Johnny and Adam are teenage surfers who live i...  sport
# 40111  Joe Waters (Joe Pesci) and Gus Green (Danny Gl...  sport
# 40112  A hard-partying section of the school, Section...  sport
# 40113  This film is about a young aspiring Cricketer ...  sport
# 40115  Subramaniam is a lower-middle-class widower wi...  sport
# 40117  Wade Watts is a teenager who lives in a slum w...  sport
# 40118  Catana Starks is the coach for the women's swi...  sport
# 40119  Andy "Brink" Brinker and his in-line skating c...  sport
# 40120  Daniel Kintner and Susan Watkins are frustrate...  sport
# 40121  The film opens with Mäddy Killian (Caitlin Sta...  sport

# %%
df.Genre.value_counts()
# Out:
# drama              8098
# comedy             6501
# adventure          2818
# science fiction    2719
# western            2660
# thriller           2516
# action             2116
# musical            1827
# noir               1713
# horror             1355
# romance            1332
# fantasy             827
# animation           811
# war                 534
# sport               409
# documentary         354
# family              319
# historical          253
# biography           219
# Name: Genre, dtype: int64

# %% [markdown]
# ## SVM

# %%
from sklearn.model_selection import train_test_split

X = df['Plot'].values
y = df['Genre'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, stratify=y, shuffle=True)

# %%
len(X_train),len(y_train),len(X_test),len(y_test)
# Out:
# (26166, 26166, 11215, 11215)

# %%
import nltk
import spacy

nlp = spacy.load('en_core_web_sm')

doc_counter = 0
def reset_counter():
  global doc_counter
  doc_counter = 0

def increase_counter():
  global doc_counter
  doc_counter += 1
  if doc_counter % 100 == 0:
    print(doc_counter)

def spacy_nlp_tokenizer(text):
    increase_counter()
        
    # we use spacy for main nlp tasks
    doc = nlp(text)
    # lemmatized tokens, skipping stopwords
    lemmas = ['LEMMA_'+token.lemma_ for token in doc if not token.is_stop]
    # entity_types
    # entity_types = ['NER_'+token.ent_type_ for token in doc if token.ent_type_]

    # in case an entity linker is available, we can use it do put actual entities as
    # features, e.g. Queen Elizabeth, Elizabeth II, Her Majesty -> KB2912
    # see https://spacy.io/usage/training#entity-linker
    # entities = ['ENT_'+token.ent_kb_id_ for token in doc if token.ent_kb_id_]

    # we use a simple nltk function to create ngrams
    lemma_bigrams = ['BI_'+p1+'_'+p2 for p1,p2 in nltk.ngrams(lemmas,2)]
    lemma_trigrams = ['TRI_'+p1+'_'+p2+'_'+p3 for p1,p2,p3 in nltk.ngrams(lemmas,3)]

    all_tokens = list()
    all_tokens.extend(lemmas)
    all_tokens.extend(lemma_bigrams)
    all_tokens.extend(lemma_trigrams)
    #all_tokens.extend(entity_types)
    return all_tokens

# %%
from sklearn.feature_extraction.text import CountVectorizer

vect = CountVectorizer(analyzer=spacy_nlp_tokenizer, min_df=5)

X_train_tok = vect.fit_transform(X_train)

X_test_tok = vect.transform(X_test)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000
# 25100
# 25200
# 25300
# 25400
# 25500
# 25600
# 25700
# 25800
# 25900
# 26000
# 26100
# 26200
# 26300
# 26400
# 26500
# 26600
# 26700
# 26800
# 26900
# 27000
# 27100
# 27200
# 27300
# 27400
# 27500
# 27600
# 27700
# 27800
# 27900
# 28000
# 28100
# 28200
# 28300
# 28400
# 28500
# 28600
# 28700
# 28800
# 28900
# 29000
# 29100
# 29200
# 29300
# 29400
# 29500
# 29600
# 29700
# 29800
# 29900
# 30000
# 30100
# 30200
# 30300
# 30400
# 30500
# 30600
# 30700
# 30800
# 30900
# 31000
# 31100
# 31200
# 31300
# 31400
# 31500
# 31600
# 31700
# 31800
# 31900
# 32000
# 32100
# 32200
# 32300
# 32400
# 32500
# 32600
# 32700
# 32800
# 32900
# 33000
# 33100
# 33200
# 33300
# 33400
# 33500
# 33600
# 33700
# 33800
# 33900
# 34000
# 34100
# 34200
# 34300
# 34400
# 34500
# 34600
# 34700
# 34800
# 34900
# 35000
# 35100
# 35200
# 35300
# 35400
# 35500
# 35600
# 35700
# 35800
# 35900
# 36000
# 36100
# 36200
# 36300
# 36400
# 36500
# 36600
# 36700
# 36800
# 36900
# 37000
# 37100
# 37200
# 37300

# %%
X_train_tok.shape, X_test_tok.shape
# Out:
# ((26166, 245531), (11215, 245531))

# %%
#writing features to pickle
import pickle

with open('x_train_tok.pkl','wb') as train_outfile:
    pickle.dump(X_train_tok,train_outfile)
with open('x_test_tok.pkl','wb') as test_outfile:
    pickle.dump(X_test_tok,test_outfile)

# %%
#reading from pickle
import pickle

with open('x_train_tok.pkl','rb') as train_file:
    X_train_tok = pickle.load(train_file)

with open('x_test_tok.pkl','rb') as test_file:
    X_test_tok = pickle.load(test_file)

# %%
X_train_tok.shape, X_test_tok.shape
# Out:
# ((29904, 281835), (7477, 281835))

# %%
for feat,freq in zip(vect.inverse_transform(X_train_tok[0,:])[0],X_train_tok[0,:].data):
    print(feat,freq)
# Out:
# LEMMA_opening 3
# LEMMA_scene 4
# LEMMA_, 63
# LEMMA_24 1
# LEMMA_- 10
# LEMMA_year 8
# LEMMA_old 1
# LEMMA_" 14
# LEMMA_Alice 23
# LEMMA_Ayres 2
# LEMMA_( 7
# LEMMA_Portman 1
# LEMMA_) 7
# LEMMA_Dan 30
# LEMMA_Woolf 1
# LEMMA_Law 1
# LEMMA_time 2
# LEMMA_opposite 1
# LEMMA_side 1
# LEMMA_street 3
# LEMMA_walk 2
# LEMMA_rush 2
# LEMMA_hour 1
# LEMMA_pedestrian 1
# LEMMA_. 50
# LEMMA_young 3
# LEMMA_american 2
# LEMMA_stripper 2
# LEMMA_arrive 2
# LEMMA_London 4
# LEMMA_unsuccessful 1
# LEMMA_british 2
# LEMMA_writer 1
# LEMMA_way 3
# LEMMA_work 2
# LEMMA_write 2
# LEMMA_obituary 1
# LEMMA_newspaper 1
# LEMMA_look 1
# LEMMA_wrong 1
# LEMMA_direction 1
# LEMMA_cross 1
# LEMMA_hit 2
# LEMMA_taxi 1
# LEMMA_cab 1
# LEMMA_right 2
# LEMMA_eye 1
# LEMMA_smile 1
# LEMMA_say 1
# LEMMA_hello 1
# LEMMA_strange 1
# LEMMA_take 4
# LEMMA_hospital 1
# LEMMA_treat 1
# LEMMA_release 1
# LEMMA_afterward 1
# LEMMA_office 2
# LEMMA_stop 1
# LEMMA_Park 2
# LEMMA_park 1
# LEMMA_father 1
# LEMMA_visit 1
# LEMMA_mother 1
# LEMMA_death 1
# LEMMA_pause 1
# LEMMA_leave 6
# LEMMA_go 5
# LEMMA_remind 1
# LEMMA_traffic 1
# LEMMA_England 1
# LEMMA_tend 1
# LEMMA_come 2
# LEMMA_impulse 2
# LEMMA_ask 6
# LEMMA_soon 2
# LEMMA_lover 2
# LEMMA_
#  8
# LEMMA_later 3
# LEMMA_relationship 4
# LEMMA_stray 1
# LEMMA_novel 1
# LEMMA_base 1
# LEMMA_life 2
# LEMMA_photograph 4
# LEMMA_publicize 1
# LEMMA_flirt 1
# LEMMA_photographer 1
# LEMMA_Anna 22
# LEMMA_Cameron 1
# LEMMA_Roberts 1
# LEMMA_share 1
# LEMMA_kiss 1
# LEMMA_find 1
# LEMMA_use 1
# LEMMA_bathroom 1
# LEMMA_chance 1
# LEMMA_try 2
# LEMMA_persuade 1
# LEMMA_affair 3
# LEMMA_cut 1
# LEMMA_short 1
# LEMMA_return 5
# LEMMA_portrait 1
# LEMMA_agree 3
# LEMMA_photo 2
# LEMMA_shoot 1
# LEMMA_reveal 3
# LEMMA_overhear 2
# LEMMA_weep 1
# LEMMA_spend 1
# LEMMA_stalk 1
# LEMMA_enter 1
# LEMMA_chat 1
# LEMMA_room 2
# LEMMA_randomly 1
# LEMMA_meet 5
# LEMMA_Larry 17
# LEMMA_Gray 1
# LEMMA_Clive 1
# LEMMA_Owen 1
# LEMMA_mind 1
# LEMMA_pretend 1
# LEMMA_pretense 1
# LEMMA_have 1
# LEMMA_sex 1
# LEMMA_convince 4
# LEMMA_aquarium 1
# LEMMA_tell 8
# LEMMA_rendezvous 1
# LEMMA_rude 1
# LEMMA_awakening 1
# LEMMA_man 1
# LEMMA_pursue 1
# LEMMA_likely 1
# LEMMA_blame 1
# LEMMA_setup 1
# LEMMA_couple 2
# LEMMA_refer 1
# LEMMA_Cupid 1
# LEMMA_month 1
# LEMMA_] 1
# LEMMA_recognize 1
# LEMMA_tearful 1
# LEMMA_exhibit 1
# LEMMA_know 1
# LEMMA_talk 1
# LEMMA_involved 1
# LEMMA_begin 1
# LEMMA_cheat 1
# LEMMA_respective 2
# LEMMA_marry 1
# LEMMA_halfway 1
# LEMMA_eventually 2
# LEMMA_confes 1
# LEMMA_partner 1
# LEMMA_heartbroken 1
# LEMMA_loss 1
# LEMMA_day 1
# LEMMA_run 1
# LEMMA_accidentally 1
# LEMMA_strip 1
# LEMMA_club 1
# LEMMA_heart 1
# LEMMA_break 1
# LEMMA_girl 1
# LEMMA_matter 1
# LEMMA_money 1
# LEMMA_give 1
# LEMMA_keeps 1
# LEMMA_Jane 4
# LEMMA_Jones 2
# LEMMA_night 4
# LEMMA_stand 4
# LEMMA_refuse 1
# LEMMA_line 1
# LEMMA_questioning 1
# LEMMA_pornographic 1
# LEMMA_albeit 1
# LEMMA_explicit 1
# LEMMA_nudity 1
# LEMMA_; 1
# LEMMA_sleep 2
# LEMMA_sign 1
# LEMMA_divorce 1
# LEMMA_paper 1
# LEMMA_suspect 1
# LEMMA_confess 1
# LEMMA_follow 1
# LEMMA_argument 2
# LEMMA_Distraught 1
# LEMMA_confront 1
# LEMMA_instead 1
# LEMMA_whereabouts 1
# LEMMA_suggest 1
# LEMMA_suddenly 2
# LEMMA_sheer 1
# LEMMA_malicious 1
# LEMMA_decide 1
# LEMMA_want 1
# LEMMA_home 1
# LEMMA_country 1
# LEMMA_invite 1
# LEMMA_hotel 1
# LEMMA_celebrate 1
# LEMMA_note 1
# LEMMA_car 1
# LEMMA_initially 1
# LEMMA_deny 1
# LEMMA_insist 2
# LEMMA_truth 1
# LEMMA_love 1
# LEMMA_anymore 1
# LEMMA_forgive 1
# LEMMA_culminate 1
# LEMMA_slap 1
# LEMMA_end 1
# LEMMA_New 1
# LEMMA_York 1
# LEMMA_pass 1
# LEMMA_immigration 1
# LEMMA_checkpoint 1
# LEMMA_United 1
# LEMMA_States 1
# LEMMA_shot 1
# LEMMA_passport 1
# LEMMA_show 2
# LEMMA_real 1
# LEMMA_Rachel 1
# LEMMA_lie 1
# LEMMA_surprise 1
# LEMMA_notice 1
# LEMMA_memorial 1
# LEMMA_dedicate 1
# LEMMA_woman 1
# LEMMA_intrepid 1
# LEMMA_conduct 1
# LEMMA_cost 1
# LEMMA_rescue 1
# LEMMA_child 1
# LEMMA_fire 1
# LEMMA_final 1
# LEMMA_/ 2
# LEMMA_Broadway 1
# LEMMA_West 1
# LEMMA_Street 1
# LEMMA_male 1
# LEMMA_passer 1
# LEMMA_stare 2
# LEMMA_beauty 1
# LEMMA_complete 1
# LEMMA_visual 1
# LEMMA_film 1
# LEMMA_echo 1
# LEMMA_sidewalk 1
# BI_LEMMA_opening_LEMMA_scene 3
# BI_LEMMA_scene_LEMMA_, 1
# BI_LEMMA_,_LEMMA_24 1
# BI_LEMMA_24_LEMMA_- 1
# BI_LEMMA_-_LEMMA_year 2
# BI_LEMMA_year_LEMMA_- 1
# BI_LEMMA_-_LEMMA_old 1
# BI_LEMMA_old_LEMMA_" 1
# BI_LEMMA_"_LEMMA_Alice 3
# BI_LEMMA_"_LEMMA_( 1
# BI_LEMMA_Portman_LEMMA_) 1
# BI_LEMMA_)_LEMMA_Dan 1
# BI_LEMMA_Law_LEMMA_) 1
# BI_LEMMA_)_LEMMA_time 1
# BI_LEMMA_opposite_LEMMA_side 1
# BI_LEMMA_-_LEMMA_hour 1
# BI_LEMMA_pedestrian_LEMMA_. 1
# BI_LEMMA_._LEMMA_" 3
# BI_LEMMA_Alice_LEMMA_" 1
# BI_LEMMA_"_LEMMA_young 1
# BI_LEMMA_young_LEMMA_american 1
# BI_LEMMA_arrive_LEMMA_London 1
# BI_LEMMA_London_LEMMA_, 2
# BI_LEMMA_,_LEMMA_Dan 11
# BI_LEMMA_british_LEMMA_writer 1
# BI_LEMMA_way_LEMMA_work 1
# BI_LEMMA_work_LEMMA_, 2
# BI_LEMMA_,_LEMMA_write 1
# BI_LEMMA_newspaper_LEMMA_. 1
# BI_LEMMA_._LEMMA_look 1
# BI_LEMMA_wrong_LEMMA_direction 1
# BI_LEMMA_cross_LEMMA_street 1
# BI_LEMMA_street_LEMMA_hit 1
# BI_LEMMA_hit_LEMMA_taxi 1
# BI_LEMMA_taxi_LEMMA_cab 1
# BI_LEMMA_eye_LEMMA_. 1
# BI_LEMMA_._LEMMA_rush 1
# BI_LEMMA_rush_LEMMA_, 1
# BI_LEMMA_,_LEMMA_smile 1
# BI_LEMMA_smile_LEMMA_say 1
# BI_LEMMA_say_LEMMA_, 1
# BI_LEMMA_,_LEMMA_" 2
# BI_LEMMA_"_LEMMA_hello 1
# BI_LEMMA_hello_LEMMA_, 1
# BI_LEMMA_,_LEMMA_strange 1
# BI_LEMMA_strange_LEMMA_. 1
# BI_LEMMA_"_LEMMA_take 1
# BI_LEMMA_take_LEMMA_hospital 1
# BI_LEMMA_hospital_LEMMA_, 1
# BI_LEMMA_,_LEMMA_Alice 2
# BI_LEMMA_release_LEMMA_. 1
# BI_LEMMA_._LEMMA_afterward 1
# BI_LEMMA_afterward_LEMMA_, 1
# BI_LEMMA_,_LEMMA_way 1
# BI_LEMMA_way_LEMMA_office 1
# BI_LEMMA_office_LEMMA_, 1
# BI_LEMMA_,_LEMMA_stop 1
# BI_LEMMA_Park_LEMMA_, 2
# BI_LEMMA_,_LEMMA_park 1
# BI_LEMMA_father_LEMMA_visit 1
# BI_LEMMA_visit_LEMMA_mother 1
# BI_LEMMA_mother_LEMMA_death 1
# BI_LEMMA_death_LEMMA_. 1
# BI_LEMMA_._LEMMA_pause 1
# BI_LEMMA_leave_LEMMA_go 1
# BI_LEMMA_go_LEMMA_work 1
# BI_LEMMA_come_LEMMA_right 1
# BI_LEMMA_right_LEMMA_, 1
# BI_LEMMA_impulse_LEMMA_, 2
# BI_LEMMA_,_LEMMA_ask 1
# BI_LEMMA_ask_LEMMA_. 1
# BI_LEMMA_._LEMMA_soon 2
# BI_LEMMA_soon_LEMMA_lover 1
# BI_LEMMA_lover_LEMMA_. 1
# BI_LEMMA_._LEMMA_
#  8
# BI_LEMMA_
# _LEMMA_year 2
# BI_LEMMA_year_LEMMA_later 2
# BI_LEMMA_later_LEMMA_, 3
# BI_LEMMA_,_LEMMA_relationship 1
# BI_LEMMA_relationship_LEMMA_, 1
# BI_LEMMA_stray_LEMMA_. 1
# BI_LEMMA_._LEMMA_write 1
# BI_LEMMA_write_LEMMA_novel 1
# BI_LEMMA_novel_LEMMA_base 1
# BI_LEMMA_life_LEMMA_, 2
# BI_LEMMA_,_LEMMA_photograph 2
# BI_LEMMA_,_LEMMA_flirt 1
# BI_LEMMA_american_LEMMA_photographer 1
# BI_LEMMA_Cameron_LEMMA_( 1
# BI_LEMMA_(_LEMMA_Roberts 1
# BI_LEMMA_Roberts_LEMMA_) 1
# BI_LEMMA_)_LEMMA_. 2
# BI_LEMMA_._LEMMA_Anna 4
# BI_LEMMA_share_LEMMA_kiss 1
# BI_LEMMA_Dan_LEMMA_find 1
# BI_LEMMA_find_LEMMA_Dan 1
# BI_LEMMA_relationship_LEMMA_. 2
# BI_LEMMA_._LEMMA_Alice 4
# BI_LEMMA_Alice_LEMMA_arrive 1
# BI_LEMMA_arrive_LEMMA_use 1
# BI_LEMMA_bathroom_LEMMA_, 1
# BI_LEMMA_,_LEMMA_leave 2
# BI_LEMMA_leave_LEMMA_Anna 1
# BI_LEMMA_Dan_LEMMA_. 3
# BI_LEMMA_._LEMMA_Dan 3
# BI_LEMMA_Dan_LEMMA_take 1
# BI_LEMMA_take_LEMMA_chance 1
# BI_LEMMA_chance_LEMMA_try 1
# BI_LEMMA_try_LEMMA_persuade 1
# BI_LEMMA_affair_LEMMA_, 2
# BI_LEMMA_,_LEMMA_cut 1
# BI_LEMMA_cut_LEMMA_short 1
# BI_LEMMA_Alice_LEMMA_return 2
# BI_LEMMA_return_LEMMA_. 1
# BI_LEMMA_Alice_LEMMA_ask 2
# BI_LEMMA_ask_LEMMA_Anna 1
# BI_LEMMA_take_LEMMA_, 1
# BI_LEMMA_,_LEMMA_. 1
# BI_LEMMA_Anna_LEMMA_agree 1
# BI_LEMMA_Dan_LEMMA_leave 1
# BI_LEMMA_leave_LEMMA_photo 1
# BI_LEMMA_photo_LEMMA_shoot 1
# BI_LEMMA_shoot_LEMMA_. 1
# BI_LEMMA_._LEMMA_photograph 1
# BI_LEMMA_photograph_LEMMA_, 1
# BI_LEMMA_,_LEMMA_reveal 1
# BI_LEMMA_reveal_LEMMA_Anna 1
# BI_LEMMA_overhear_LEMMA_, 1
# BI_LEMMA_weep_LEMMA_. 1
# BI_LEMMA_Alice_LEMMA_reveal 1
# BI_LEMMA_Dan_LEMMA_, 2
# BI_LEMMA_,_LEMMA_spend 1
# BI_LEMMA_spend_LEMMA_year 1
# BI_LEMMA_Anna_LEMMA_. 3
# BI_LEMMA_chat_LEMMA_room 1
# BI_LEMMA_meet_LEMMA_Larry 1
# BI_LEMMA_Gray_LEMMA_( 1
# BI_LEMMA_(_LEMMA_Clive 1
# BI_LEMMA_Clive_LEMMA_Owen 1
# BI_LEMMA_Owen_LEMMA_) 1
# BI_LEMMA_)_LEMMA_, 2
# BI_LEMMA_,_LEMMA_british 1
# BI_LEMMA_mind_LEMMA_, 1
# BI_LEMMA_pretend_LEMMA_, 1
# BI_LEMMA_,_LEMMA_pretense 1
# BI_LEMMA_have_LEMMA_sex 1
# BI_LEMMA_sex_LEMMA_, 1
# BI_LEMMA_Dan_LEMMA_convince 2
# BI_LEMMA_convince_LEMMA_Larry 1
# BI_LEMMA_Larry_LEMMA_meet 2
# BI_LEMMA_(_LEMMA_Anna 1
# BI_LEMMA_Anna_LEMMA_tell 2
# BI_LEMMA_tell_LEMMA_Dan 1
# BI_LEMMA_Dan_LEMMA_go 1
# BI_LEMMA_go_LEMMA_) 1
# BI_LEMMA_._LEMMA_Larry 2
# BI_LEMMA_Larry_LEMMA_go 1
# BI_LEMMA_awakening_LEMMA_. 1
# BI_LEMMA_tell_LEMMA_Larry 1
# BI_LEMMA_man_LEMMA_pursue 1
# BI_LEMMA_pursue_LEMMA_, 1
# BI_LEMMA_,_LEMMA_likely 1
# BI_LEMMA_setup_LEMMA_. 1
# BI_LEMMA_soon_LEMMA_, 1
# BI_LEMMA_,_LEMMA_Anna 4
# BI_LEMMA_Dan_LEMMA_" 1
# BI_LEMMA_"_LEMMA_. 1
# BI_LEMMA_
# _LEMMA_month 1
# BI_LEMMA_month_LEMMA_later 1
# BI_LEMMA_meet_LEMMA_Alice 1
# BI_LEMMA_Alice_LEMMA_, 2
# BI_LEMMA_,_LEMMA_recognize 1
# BI_LEMMA_exhibit_LEMMA_. 1
# BI_LEMMA_Larry_LEMMA_know 1
# BI_LEMMA_know_LEMMA_Alice 1
# BI_LEMMA_couple_LEMMA_, 1
# BI_LEMMA_,_LEMMA_talk 1
# BI_LEMMA_._LEMMA_, 1
# BI_LEMMA_convince_LEMMA_Anna 2
# BI_LEMMA_involved_LEMMA_. 1
# BI_LEMMA_._LEMMA_begin 1
# BI_LEMMA_begin_LEMMA_cheat 1
# BI_LEMMA_respective_LEMMA_lover 1
# BI_LEMMA_lover_LEMMA_year 1
# BI_LEMMA_year_LEMMA_, 1
# BI_LEMMA_Larry_LEMMA_marry 1
# BI_LEMMA_year_LEMMA_. 1
# BI_LEMMA_._LEMMA_eventually 1
# BI_LEMMA_respective_LEMMA_partner 1
# BI_LEMMA_partner_LEMMA_, 1
# BI_LEMMA_leave_LEMMA_relationship 1
# BI_LEMMA_
# _LEMMA_Alice 2
# BI_LEMMA_Alice_LEMMA_go 1
# BI_LEMMA_stripper_LEMMA_, 1
# BI_LEMMA_,_LEMMA_heartbroken 1
# BI_LEMMA_heartbroken_LEMMA_loss 1
# BI_LEMMA_loss_LEMMA_. 1
# BI_LEMMA_._LEMMA_day 1
# BI_LEMMA_day_LEMMA_, 1
# BI_LEMMA_,_LEMMA_Larry 4
# BI_LEMMA_strip_LEMMA_club 1
# BI_LEMMA_club_LEMMA_( 1
# BI_LEMMA_(_LEMMA_heart 1
# BI_LEMMA_heart_LEMMA_- 1
# BI_LEMMA_-_LEMMA_break 1
# BI_LEMMA_break_LEMMA_) 1
# BI_LEMMA_)_LEMMA_convince 1
# BI_LEMMA_convince_LEMMA_girl 1
# BI_LEMMA_girl_LEMMA_meet 1
# BI_LEMMA_meet_LEMMA_. 1
# BI_LEMMA_._LEMMA_ask 1
# BI_LEMMA_ask_LEMMA_Alice 1
# BI_LEMMA_,_LEMMA_matter 1
# BI_LEMMA_money_LEMMA_give 1
# BI_LEMMA_give_LEMMA_, 1
# BI_LEMMA_,_LEMMA_keeps 1
# BI_LEMMA_tell_LEMMA_" 1
# BI_LEMMA_"_LEMMA_Jane 1
# BI_LEMMA_Jones_LEMMA_. 2
# BI_LEMMA_"_LEMMA_ask 1
# BI_LEMMA_ask_LEMMA_- 2
# BI_LEMMA_-_LEMMA_night 4
# BI_LEMMA_night_LEMMA_stand 4
# BI_LEMMA_refuse_LEMMA_. 1
# BI_LEMMA_._LEMMA_line 1
# BI_LEMMA_,_LEMMA_albeit 1
# BI_LEMMA_
# _LEMMA_eventually 1
# BI_LEMMA_eventually_LEMMA_, 1
# BI_LEMMA_Larry_LEMMA_convince 1
# BI_LEMMA_time_LEMMA_; 1
# BI_LEMMA_;_LEMMA_agree 1
# BI_LEMMA_sign_LEMMA_divorce 1
# BI_LEMMA_divorce_LEMMA_paper 1
# BI_LEMMA_paper_LEMMA_leave 1
# BI_LEMMA_leave_LEMMA_. 2
# BI_LEMMA_suspect_LEMMA_affair 1
# BI_LEMMA_confess_LEMMA_, 1
# BI_LEMMA_,_LEMMA_follow 1
# BI_LEMMA_follow_LEMMA_argument 1
# BI_LEMMA_argument_LEMMA_, 1
# BI_LEMMA_,_LEMMA_return 1
# BI_LEMMA_Larry_LEMMA_. 2
# BI_LEMMA_._LEMMA_Distraught 1
# BI_LEMMA_Distraught_LEMMA_, 1
# BI_LEMMA_Larry_LEMMA_try 1
# BI_LEMMA_._LEMMA_instead 1
# BI_LEMMA_instead_LEMMA_, 1
# BI_LEMMA_Larry_LEMMA_tell 2
# BI_LEMMA_tell_LEMMA_Alice 1
# BI_LEMMA_whereabouts_LEMMA_, 1
# BI_LEMMA_,_LEMMA_suggest 1
# BI_LEMMA_suggest_LEMMA_. 1
# BI_LEMMA_._LEMMA_suddenly 1
# BI_LEMMA_suddenly_LEMMA_, 1
# BI_LEMMA_,_LEMMA_, 1
# BI_LEMMA_,_LEMMA_sheer 1
# BI_LEMMA_,_LEMMA_tell 1
# BI_LEMMA_tell_LEMMA_- 2
# BI_LEMMA_stand_LEMMA_. 1
# BI_LEMMA_Alice_LEMMA_take 1
# BI_LEMMA_take_LEMMA_Dan 1
# BI_LEMMA_Alice_LEMMA_decide 1
# BI_LEMMA_decide_LEMMA_want 1
# BI_LEMMA_want_LEMMA_return 1
# BI_LEMMA_return_LEMMA_home 1
# BI_LEMMA_home_LEMMA_country 1
# BI_LEMMA_Dan_LEMMA_come 1
# BI_LEMMA_agree_LEMMA_. 1
# BI_LEMMA_._LEMMA_hotel 1
# BI_LEMMA_hotel_LEMMA_room 1
# BI_LEMMA_celebrate_LEMMA_( 1
# BI_LEMMA_(_LEMMA_note 1
# BI_LEMMA_year_LEMMA_meet 1
# BI_LEMMA_meet_LEMMA_London 1
# BI_LEMMA_London_LEMMA_street 1
# BI_LEMMA_hit_LEMMA_car 1
# BI_LEMMA_scene_LEMMA_) 1
# BI_LEMMA_Dan_LEMMA_ask 1
# BI_LEMMA_Larry_LEMMA_, 1
# BI_LEMMA_,_LEMMA_initially 1
# BI_LEMMA_initially_LEMMA_deny 1
# BI_LEMMA_deny_LEMMA_. 1
# BI_LEMMA_._LEMMA_insist 2
# BI_LEMMA_truth_LEMMA_, 1
# BI_LEMMA_,_LEMMA_suddenly 1
# BI_LEMMA_tell_LEMMA_love 1
# BI_LEMMA_love_LEMMA_anymore 1
# BI_LEMMA_go_LEMMA_sleep 1
# BI_LEMMA_Dan_LEMMA_reveal 1
# BI_LEMMA_forgive_LEMMA_. 1
# BI_LEMMA_insist_LEMMA_tell 1
# BI_LEMMA_tell_LEMMA_leave 1
# BI_LEMMA_._LEMMA_argument 1
# BI_LEMMA_Alice_LEMMA_. 1
# BI_LEMMA_
# _LEMMA_end 1
# BI_LEMMA_end_LEMMA_, 1
# BI_LEMMA_Anna_LEMMA_, 1
# BI_LEMMA_return_LEMMA_New 1
# BI_LEMMA_New_LEMMA_York 1
# BI_LEMMA_York_LEMMA_. 1
# BI_LEMMA_._LEMMA_pass 1
# BI_LEMMA_way_LEMMA_United 1
# BI_LEMMA_United_LEMMA_States 1
# BI_LEMMA_States_LEMMA_, 1
# BI_LEMMA_,_LEMMA_shot 1
# BI_LEMMA_show_LEMMA_real 1
# BI_LEMMA_._LEMMA_lie 1
# BI_LEMMA_lie_LEMMA_- 1
# BI_LEMMA_year_LEMMA_relationship 1
# BI_LEMMA_
# _LEMMA_London 1
# BI_LEMMA_Dan_LEMMA_return 1
# BI_LEMMA_,_LEMMA_surprise 1
# BI_LEMMA_surprise_LEMMA_, 1
# BI_LEMMA_,_LEMMA_notice 1
# BI_LEMMA_notice_LEMMA_" 1
# BI_LEMMA_young_LEMMA_woman 1
# BI_LEMMA_woman_LEMMA_, 1
# BI_LEMMA_conduct_LEMMA_" 1
# BI_LEMMA_"_LEMMA_cost 1
# BI_LEMMA_young_LEMMA_life 1
# BI_LEMMA_,_LEMMA_rescue 1
# BI_LEMMA_rescue_LEMMA_child 1
# BI_LEMMA_fire_LEMMA_. 1
# BI_LEMMA_._LEMMA_final 1
# BI_LEMMA_final_LEMMA_scene 1
# BI_LEMMA_scene_LEMMA_show 1
# BI_LEMMA_passer_LEMMA_- 1
# BI_LEMMA_beauty_LEMMA_. 1
# BI_LEMMA_._LEMMA_complete 1
# BI_LEMMA_London_LEMMA_. 1
# TRI_LEMMA_opening_LEMMA_scene_LEMMA_, 1
# TRI_LEMMA_,_LEMMA_24_LEMMA_- 1
# TRI_LEMMA_24_LEMMA_-_LEMMA_year 1
# TRI_LEMMA_-_LEMMA_year_LEMMA_- 1
# TRI_LEMMA_year_LEMMA_-_LEMMA_old 1
# TRI_LEMMA_-_LEMMA_old_LEMMA_" 1
# TRI_LEMMA_"_LEMMA_Alice_LEMMA_" 1
# TRI_LEMMA_arrive_LEMMA_London_LEMMA_, 1
# TRI_LEMMA_way_LEMMA_work_LEMMA_, 1
# TRI_LEMMA_._LEMMA_rush_LEMMA_, 1
# TRI_LEMMA_smile_LEMMA_say_LEMMA_, 1
# TRI_LEMMA_say_LEMMA_,_LEMMA_" 1
# TRI_LEMMA_,_LEMMA_"_LEMMA_hello 1
# TRI_LEMMA_"_LEMMA_hello_LEMMA_, 1
# TRI_LEMMA_._LEMMA_"_LEMMA_take 1
# TRI_LEMMA_take_LEMMA_hospital_LEMMA_, 1
# TRI_LEMMA_._LEMMA_afterward_LEMMA_, 1
# TRI_LEMMA_mother_LEMMA_death_LEMMA_. 1
# TRI_LEMMA_go_LEMMA_work_LEMMA_, 1
# TRI_LEMMA_,_LEMMA_ask_LEMMA_. 1
# TRI_LEMMA_lover_LEMMA_._LEMMA_
#  1
# TRI_LEMMA_._LEMMA_
# _LEMMA_year 2
# TRI_LEMMA_
# _LEMMA_year_LEMMA_later 2
# TRI_LEMMA_year_LEMMA_later_LEMMA_, 2
# TRI_LEMMA_,_LEMMA_relationship_LEMMA_, 1
# TRI_LEMMA_(_LEMMA_Roberts_LEMMA_) 1
# TRI_LEMMA_Roberts_LEMMA_)_LEMMA_. 1
# TRI_LEMMA_)_LEMMA_._LEMMA_Anna 1
# TRI_LEMMA_._LEMMA_Alice_LEMMA_arrive 1
# TRI_LEMMA_,_LEMMA_leave_LEMMA_Anna 1
# TRI_LEMMA_._LEMMA_Dan_LEMMA_take 1
# TRI_LEMMA_,_LEMMA_cut_LEMMA_short 1
# TRI_LEMMA_photo_LEMMA_shoot_LEMMA_. 1
# TRI_LEMMA_,_LEMMA_spend_LEMMA_year 1
# TRI_LEMMA_Anna_LEMMA_._LEMMA_
#  1
# TRI_LEMMA_(_LEMMA_Clive_LEMMA_Owen 1
# TRI_LEMMA_Clive_LEMMA_Owen_LEMMA_) 1
# TRI_LEMMA_Owen_LEMMA_)_LEMMA_, 1
# TRI_LEMMA_)_LEMMA_,_LEMMA_british 1
# TRI_LEMMA_have_LEMMA_sex_LEMMA_, 1
# TRI_LEMMA_,_LEMMA_Dan_LEMMA_convince 2
# TRI_LEMMA_)_LEMMA_._LEMMA_Larry 1
# TRI_LEMMA_._LEMMA_Larry_LEMMA_go 1
# TRI_LEMMA_._LEMMA_Anna_LEMMA_tell 1
# TRI_LEMMA_man_LEMMA_pursue_LEMMA_, 1
# TRI_LEMMA_,_LEMMA_Dan_LEMMA_, 1
# TRI_LEMMA_._LEMMA_soon_LEMMA_, 1
# TRI_LEMMA_"_LEMMA_._LEMMA_
#  1
# TRI_LEMMA_._LEMMA_
# _LEMMA_month 1
# TRI_LEMMA_
# _LEMMA_month_LEMMA_later 1
# TRI_LEMMA_month_LEMMA_later_LEMMA_, 1
# TRI_LEMMA_later_LEMMA_,_LEMMA_Anna 1
# TRI_LEMMA_Anna_LEMMA_._LEMMA_, 1
# TRI_LEMMA_._LEMMA_,_LEMMA_Dan 1
# TRI_LEMMA_year_LEMMA_._LEMMA_eventually 1
# TRI_LEMMA_relationship_LEMMA_._LEMMA_
#  1
# TRI_LEMMA_._LEMMA_
# _LEMMA_Alice 2
# TRI_LEMMA_._LEMMA_day_LEMMA_, 1
# TRI_LEMMA_heart_LEMMA_-_LEMMA_break 1
# TRI_LEMMA_girl_LEMMA_meet_LEMMA_. 1
# TRI_LEMMA_meet_LEMMA_._LEMMA_ask 1
# TRI_LEMMA_._LEMMA_"_LEMMA_ask 1
# TRI_LEMMA_-_LEMMA_night_LEMMA_stand 4
# TRI_LEMMA_._LEMMA_
# _LEMMA_eventually 1
# TRI_LEMMA_
# _LEMMA_eventually_LEMMA_, 1
# TRI_LEMMA_sign_LEMMA_divorce_LEMMA_paper 1
# TRI_LEMMA_._LEMMA_instead_LEMMA_, 1
# TRI_LEMMA_,_LEMMA_Larry_LEMMA_tell 1
# TRI_LEMMA_._LEMMA_suddenly_LEMMA_, 1
# TRI_LEMMA_,_LEMMA_tell_LEMMA_- 1
# TRI_LEMMA_night_LEMMA_stand_LEMMA_. 1
# TRI_LEMMA_stand_LEMMA_._LEMMA_
#  1
# TRI_LEMMA_._LEMMA_Alice_LEMMA_decide 1
# TRI_LEMMA_want_LEMMA_return_LEMMA_home 1
# TRI_LEMMA_._LEMMA_hotel_LEMMA_room 1
# TRI_LEMMA_)_LEMMA_,_LEMMA_Dan 1
# TRI_LEMMA_,_LEMMA_initially_LEMMA_deny 1
# TRI_LEMMA_tell_LEMMA_leave_LEMMA_. 1
# TRI_LEMMA_Alice_LEMMA_._LEMMA_
#  1
# TRI_LEMMA_._LEMMA_
# _LEMMA_end 1
# TRI_LEMMA_
# _LEMMA_end_LEMMA_, 1
# TRI_LEMMA_return_LEMMA_New_LEMMA_York 1
# TRI_LEMMA_New_LEMMA_York_LEMMA_. 1
# TRI_LEMMA_way_LEMMA_United_LEMMA_States 1
# TRI_LEMMA_United_LEMMA_States_LEMMA_, 1
# TRI_LEMMA_-_LEMMA_year_LEMMA_relationship 1
# TRI_LEMMA_Dan_LEMMA_._LEMMA_
#  1
# TRI_LEMMA_._LEMMA_
# _LEMMA_London 1
# TRI_LEMMA_
# _LEMMA_London_LEMMA_, 1
# TRI_LEMMA_,_LEMMA_surprise_LEMMA_, 1
# TRI_LEMMA_young_LEMMA_woman_LEMMA_, 1
# TRI_LEMMA_woman_LEMMA_,_LEMMA_" 1
# TRI_LEMMA_,_LEMMA_rescue_LEMMA_child 1
# TRI_LEMMA_._LEMMA_final_LEMMA_scene 1
# TRI_LEMMA_final_LEMMA_scene_LEMMA_show 1

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.svm import LinearSVC
from sklearn.model_selection import GridSearchCV

param_grid = [
    {'sel__k': [1000, 2000, 5000, 10000], 'learner__C': [0.01, 0.1, 1, 10]}, 
 ]

opt_pipeline = Pipeline([
    ('sel', SelectKBest(chi2)),  # feature selection
    ('tfidf', TfidfTransformer()),  # weighting
    ('learner', LinearSVC())  # learning algorithm
])


n_jobs = 5

opt_search = GridSearchCV(opt_pipeline, param_grid, cv=5, n_jobs = n_jobs, verbose=3).fit(X_train_tok,y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits

# %%
opt_search.best_params_
# Out:
# {'learner__C': 0.1, 'learner__class_weight': None, 'sel__k': 10000}

# %%
opt_predictions = opt_search.best_estimator_.predict(X_test_tok)

correct = 0
for prediction,true_label in zip(opt_predictions, y_test):
    if prediction==true_label:
        correct += 1
print("Accuracy:\t", correct/len(opt_predictions))
# Out:
# Accuracy:	 0.5410610789121711

# %%
from sklearn.metrics import confusion_matrix, classification_report
print('Classification report:')
print(classification_report(y_test, opt_predictions))
print('Confusion matrix:')
cm = confusion_matrix(y_test, opt_predictions)
print(cm)
# Out:
# Classification report:
#                  precision    recall  f1-score   support
#
#          action       0.48      0.39      0.43       635
#       adventure       0.58      0.63      0.60       845
#       animation       0.72      0.40      0.51       243
#       biography       0.00      0.00      0.00        66
#          comedy       0.48      0.60      0.53      1950
#     documentary       0.84      0.30      0.44       106
#           drama       0.46      0.65      0.54      2430
#          family       1.00      0.02      0.04        96
#         fantasy       0.34      0.10      0.16       248
#      historical       0.00      0.00      0.00        76
#          horror       0.66      0.47      0.55       406
#         musical       0.65      0.46      0.54       548
#            noir       0.68      0.46      0.55       514
#         romance       0.35      0.15      0.21       400
# science fiction       0.68      0.80      0.74       816
#           sport       0.64      0.20      0.31       123
#        thriller       0.43      0.23      0.30       755
#             war       0.54      0.38      0.45       160
#         western       0.77      0.91      0.84       798
#
#        accuracy                           0.54     11215
#       macro avg       0.54      0.38      0.41     11215
#    weighted avg       0.54      0.54      0.52     11215
#
# Confusion matrix:
# [[ 246   42    0    0   60    0  155    0    2    0    5    2    7   25
#     34    1   33    4   19]
#  [  13  534    5    0   63    1   94    0   11    0    2   13   15    1
#     40    0    2   15   36]
#  [   4   27   97    0   43    0   20    0    7    0    3    7    0    1
#     29    1    0    0    4]
#  [   1    1    0    0   14    0   43    0    0    0    0    4    0    0
#      2    0    0    0    1]
#  [  50   51    4    0 1169    1  463    0    5    0   22   42   14   24
#     23    4   34    8   36]
#  [   0    5    1    0   12   32   44    0    0    0    0    2    1    0
#      5    1    0    2    1]
#  [  71   72    0    0  437    1 1585    0    2    0    4   22   30   44
#     21    6   76   13   46]
#  [   2   10    1    0   29    0   39    2    2    0    0    2    0    2
#      2    0    0    1    4]
#  [   5   48   10    0   54    0   42    0   25    0   10   10    3    3
#     32    0    1    1    4]
#  [   3   18    0    0    8    0   42    0    0    0    0    3    0    0
#      0    0    1    1    0]
#  [   3   15    0    0   41    0   59    0    3    0  192    5    0    2
#     64    0   16    1    5]
#  [   1   28   13    0  146    0   58    0   11    0    1  250    6    3
#     10    1    1    0   19]
#  [   5    6    2    0   39    0  140    0    1    0    4    3  237    0
#     11    0   50    0   16]
#  [  25    1    0    0   94    0  205    0    0    0    1    5    0   61
#      0    0    8    0    0]
#  [  17   28    1    0   29    0   48    0    3    0   15    4    7    0
#    650    0    5    2    7]
#  [   8    6    0    0   39    1   31    0    0    0    1    2    4    0
#      3   25    1    0    2]
#  [  53   11    0    0  119    0  298    0    2    0   29    3   23    9
#     19    0  174    3   12]
#  [   3   15    0    0   10    1   61    0    0    0    0    1    0    0
#      4    0    2   61    2]
#  [   1   10    1    0   18    1   30    0    0    0    3    2    1    0
#      1    0    2    0  728]]
# C:\Users\Jacopo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Jacopo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Jacopo\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Feature inspection

# %%
tokenizer = vect
selector = opt_search.best_estimator_.named_steps['sel']
classifier = opt_search.best_estimator_.named_steps['learner']
feature_names = tokenizer.get_feature_names()
feats_w_score = list()
for index,(selected,score) in enumerate(zip(selector.get_support(),selector.scores_)):
    feats_w_score.append((score,selected,feature_names[index]))
feats_w_score = sorted(feats_w_score)
print("BEST FEATURES")
feats_w_score[:-100:-1]
# Out:
# BEST FEATURES
# [(31960.26061009445, True, 'LEMMA_,'),
#  (25169.719175891325, True, 'LEMMA_Jerry'),
#  (23497.87765729788, True, 'LEMMA_Tom'),
#  (19414.526498037154, True, 'LEMMA_alien'),
#  (18255.576534556116, True, 'LEMMA_Bugs'),
#  (17365.15539605599, True, 'LEMMA_.'),
#  (14910.472293567726, True, 'LEMMA_Earth'),
#  (12722.514849501827, True, 'LEMMA_kill'),
#  (12543.152548994987, True, 'LEMMA_\r\n'),
#  (12275.379976263155, True, 'LEMMA_bug'),
#  (12209.715375859047, True, 'BI_LEMMA_._LEMMA_\r\n'),
#  (10449.587459661154, True, 'LEMMA_ranch'),
#  (9877.591296937513, True, 'LEMMA_ '),
#  (9364.7895934113, True, 'LEMMA_human'),
#  (9108.79876921604, True, 'LEMMA_german'),
#  (8977.904918759263, True, 'LEMMA_"'),
#  (8816.65874829676, True, 'LEMMA_planet'),
#  (8599.44459234337, True, 'LEMMA_Spike'),
#  (8553.933299941911, True, 'BI_LEMMA_(_LEMMA_"'),
#  (8547.54399197894, True, 'BI_LEMMA_._LEMMA_Tom'),
#  (8482.497431599035, True, 'BI_LEMMA_._LEMMA_ '),
#  (7778.801480808113, True, 'LEMMA_creature'),
#  (7619.040317488679, True, 'LEMMA_cat'),
#  (7614.6360395497395, True, 'BI_LEMMA_,_LEMMA_Bugs'),
#  (7165.2918134435295, True, 'LEMMA_ship'),
#  (7077.822205944422, True, 'LEMMA_mouse'),
#  (6873.092662329213, True, 'LEMMA_police'),
#  (6645.68659088523, True, 'BI_LEMMA_._LEMMA_bug'),
#  (6559.299169530318, True, 'TRI_LEMMA_"_LEMMA_)_LEMMA_.'),
#  (6551.093923669767, True, 'LEMMA_destroy'),
#  (6452.168280680643, True, 'LEMMA_Daffy'),
#  (6330.800898828713, True, 'LEMMA_Godzilla'),
#  (6259.531758589862, True, 'BI_LEMMA_._LEMMA_Jerry'),
#  (6144.751720690153, True, 'LEMMA_vampire'),
#  (6091.396920149411, True, 'LEMMA_platoon'),
#  (6085.2862461563245, True, 'BI_LEMMA_"_LEMMA_)'),
#  (6030.835178038342, True, 'LEMMA_outlaw'),
#  (5919.64280475404, True, 'LEMMA_robot'),
#  (5897.274930241953, True, 'LEMMA_attack'),
#  (5863.286190646207, True, 'BI_LEMMA_,_LEMMA_Jerry'),
#  (5858.409022958545, True, 'LEMMA_cattle'),
#  (5787.778468613445, True, 'LEMMA_soldier'),
#  (5769.753751522897, True, 'LEMMA_scientist'),
#  (5688.153247046862, True, 'LEMMA_town'),
#  (5655.33890463726, True, 'LEMMA_murder'),
#  (5651.377282991262, True, 'LEMMA_Pinocchio'),
#  (5518.808652839797, True, 'LEMMA_team'),
#  (5468.758472514346, True, 'LEMMA_Elmer'),
#  (5350.734498695987, True, 'LEMMA_love'),
#  (5325.615500511536, True, 'LEMMA_space'),
#  (5285.313154867352, True, 'LEMMA_japanese'),
#  (5251.641510965102, True, 'LEMMA_Germans'),
#  (5147.5469096571005, True, 'LEMMA_Dr.'),
#  (4957.359154929576, True, 'LEMMA_Quacker'),
#  (4838.83887068226, True, 'LEMMA_power'),
#  (4759.132522064834, True, 'LEMMA_body'),
#  (4643.801587414647, True, 'LEMMA_saloon'),
#  (4577.7316163739915, True, 'LEMMA_posse'),
#  (4512.413389744703, True, 'LEMMA_Indians'),
#  (4509.664970715953, True, 'LEMMA_escape'),
#  (4484.581283174252, True, 'LEMMA_Dracula'),
#  (4368.698124078283, True, 'LEMMA_horse'),
#  (4145.811622347468, True, 'LEMMA_!'),
#  (4082.823744093327, True, 'LEMMA_cricket'),
#  (3999.344917357791, True, 'LEMMA_spaceship'),
#  (3991.653984100896, True, 'LEMMA_Francesco'),
#  (3941.152592923564, True, 'LEMMA_shoot'),
#  (3939.692710592481, True, 'LEMMA_sheriff'),
#  (3896.6379934440392, True, 'BI_LEMMA_Jerry_LEMMA_,'),
#  (3822.113950688401, True, 'LEMMA_ride'),
#  (3785.4811373975717, True, 'LEMMA_match'),
#  (3768.2719389726567, True, 'LEMMA_crew'),
#  (3754.784428522739, True, 'LEMMA_wagon'),
#  (3739.045219165972, True, 'LEMMA_stagecoach'),
#  (3726.3504053455963, True, 'LEMMA_monster'),
#  (3726.1340907422205, True, 'LEMMA_werewolf'),
#  (3685.9622497756764, True, 'LEMMA_-'),
#  (3676.523076094136, True, 'LEMMA_dragon'),
#  (3565.4802504227077, True, 'LEMMA_rancher'),
#  (3467.6383738633463, True, 'BI_LEMMA_,_LEMMA_Tom'),
#  (3466.1143727327776, True, 'LEMMA_song'),
#  (3438.623674117343, True, 'LEMMA_documentary'),
#  (3421.933876091227, True, 'LEMMA_tournament'),
#  (3289.58150958343, True, 'LEMMA_lab'),
#  (3288.86829518511, True, 'LEMMA_sing'),
#  (3281.614994360706, True, 'LEMMA_fairy'),
#  (3269.1827447073483, True, 'LEMMA_Mozart'),
#  (3268.221937171363, True, 'LEMMA_Bingo'),
#  (3243.8104728179414, True, 'LEMMA_island'),
#  (3241.5783854058927, True, 'LEMMA_magic'),
#  (3190.1897595069063, True, 'LEMMA_King'),
#  (3163.605676634567, True, 'LEMMA_Mowgli'),
#  (3151.881806044891, True, 'LEMMA_Rahul'),
#  (3144.8596454976723, True, 'BI_LEMMA_Earth_LEMMA_.'),
#  (3109.6161971830984, True, 'LEMMA_Tyke'),
#  (3097.2177180855138, True, 'LEMMA_win'),
#  (3091.89168969858, True, 'LEMMA_find'),
#  (3078.4044879271655, True, 'LEMMA_house'),
#  (3050.1496248755234, True, 'LEMMA_Porky')]

# %%
feats_w_classifier_weight = dict()

for n, genre in enumerate(sorted(set(y_test))):
    feats_w_classifier_weight[genre] = list()
    for index,weight in enumerate(selector.inverse_transform(classifier.coef_)[n]):
        if weight!=0:
            feats_w_classifier_weight[genre].append((weight,feature_names[index]))

# %%
sorted(feats_w_classifier_weight['thriller'])[:-100:-1]
# Out:
# [(1.2342882449030586, 'LEMMA_murder'),
#  (1.0795252640393822, 'LEMMA_suspect'),
#  (0.9297482045996174, 'BI_LEMMA_._LEMMA_\r\n'),
#  (0.8693167360898718, 'LEMMA_police'),
#  (0.8531953052531958, 'LEMMA_mystery'),
#  (0.7743584620060625, 'LEMMA_phone'),
#  (0.7577972040921012, 'LEMMA_blackmailer'),
#  (0.7484058024360729, 'LEMMA_Holmes'),
#  (0.722077196362928, 'LEMMA_\r\n'),
#  (0.6729092062093767, 'LEMMA_murderer'),
#  (0.6347309762915365, 'LEMMA_killer'),
#  (0.6268576555082526, 'LEMMA_Poirot'),
#  (0.6229262446723992, 'LEMMA_London'),
#  (0.6129177131676552, 'LEMMA_detective'),
#  (0.6039835684543726, 'LEMMA_Chan'),
#  (0.600337250705263, 'LEMMA_Watson'),
#  (0.5991711505365434, 'LEMMA_criminal'),
#  (0.5871564519953145, 'LEMMA_flat'),
#  (0.5858822794309061, 'BI_LEMMA_dead_LEMMA_.'),
#  (0.5818362699519485, 'BI_LEMMA_prime_LEMMA_suspect'),
#  (0.5657130773259175, 'BI_LEMMA_find_LEMMA_dead'),
#  (0.5536142653399997, 'LEMMA_Matty'),
#  (0.5483794093207841, 'LEMMA_dead'),
#  (0.540083073727887, 'LEMMA_Police'),
#  (0.5371588626769882, 'LEMMA_shark'),
#  (0.5233524243859895, 'LEMMA_safe'),
#  (0.5123495799501977, 'LEMMA_investigation'),
#  (0.5073464720246473, 'LEMMA_target'),
#  (0.48809131854349985, 'LEMMA_solve'),
#  (0.4868459401249922, 'LEMMA_security'),
#  (0.4800422009742722, 'BI_LEMMA_murderer_LEMMA_.'),
#  (0.47592329583230475, 'BI_LEMMA_suspect_LEMMA_.'),
#  (0.4665307770401969, 'LEMMA_panic'),
#  (0.463038549256291, 'LEMMA_kill'),
#  (0.46196237904804655, 'LEMMA_innocent'),
#  (0.459402303401875, 'LEMMA_organization'),
#  (0.450575782303382, 'LEMMA_telephone'),
#  (0.4465480336343021, 'LEMMA_caller'),
#  (0.44240991204696434, 'LEMMA_Inspector'),
#  (0.4407842925299422, 'LEMMA_car'),
#  (0.43278147025933267, 'LEMMA_stab'),
#  (0.4297395495025218, 'LEMMA_russian'),
#  (0.42850172084157473, 'LEMMA_clue'),
#  (0.4274227606698923, 'LEMMA_video'),
#  (0.42133489852205314, 'LEMMA_Ana'),
#  (0.41634458728111573, 'LEMMA_abduct'),
#  (0.41253532976354174, 'LEMMA_accident'),
#  (0.4112698853740633, 'LEMMA_Tessa'),
#  (0.4091715867569518, 'LEMMA_Ashwin'),
#  (0.40890791726222875, 'LEMMA_find'),
#  (0.4054291114217701, 'LEMMA_painting'),
#  (0.40387387557760646, 'LEMMA_plane'),
#  (0.4018597306136952, 'LEMMA_Lanyard'),
#  (0.4012096113244765, 'LEMMA_suspicion'),
#  (0.39811202591206885, 'LEMMA_suspicious'),
#  (0.3963011352889193, 'LEMMA_secret'),
#  (0.3950567104470749, 'LEMMA_mysterious'),
#  (0.39468923706515524, 'LEMMA_leader'),
#  (0.39397635631145145, 'LEMMA_night'),
#  (0.39169180599872205, 'LEMMA_Rajeev'),
#  (0.3857935167941109, 'LEMMA_inside'),
#  (0.3824413313642893, 'LEMMA_Falcon'),
#  (0.3802282068997991, 'LEMMA_Sharma'),
#  (0.3795143536855177, 'LEMMA_room'),
#  (0.3792944031158623, 'BI_LEMMA_murder_LEMMA_,'),
#  (0.37616083379334203, 'LEMMA_insurance'),
#  (0.37480252181065393, 'LEMMA_deadly'),
#  (0.3733424261880481, 'TRI_LEMMA_murder_LEMMA_._LEMMA_\r\n'),
#  (0.37243302737250117, 'LEMMA_kidnap'),
#  (0.37014219748731825, 'LEMMA_draw'),
#  (0.3632731732541842, 'LEMMA_Cross'),
#  (0.36300052788782805, 'LEMMA_Torchy'),
#  (0.35466052429703016, 'LEMMA_underground'),
#  (0.3534101648028312, 'LEMMA_Rong'),
#  (0.35191003630805373, 'LEMMA_Preeti'),
#  (0.3517472126764781, 'BI_LEMMA_investigation_LEMMA_,'),
#  (0.35141486418504236, 'LEMMA_reveal'),
#  (0.3502070369360978, 'LEMMA_Annamalai'),
#  (0.34891602630628815, 'LEMMA_pull'),
#  (0.3476234339276036, 'LEMMA_Crowe'),
#  (0.3447945974430335, 'LEMMA_Hon'),
#  (0.3427682868004913, 'LEMMA_Scotland'),
#  (0.34226000661413514, 'LEMMA_stalk'),
#  (0.33755396675425225, 'BI_LEMMA_victim_LEMMA_,'),
#  (0.3365162765637424, 'LEMMA_Prabhu'),
#  (0.3329297860296877, 'BI_LEMMA_Lone_LEMMA_Wolf'),
#  (0.3326804938815567, 'LEMMA_Ripley'),
#  (0.3322058601275437, 'LEMMA_Kalyani'),
#  (0.33176391686378753, 'LEMMA_crime'),
#  (0.33131812122380483, 'LEMMA_seemingly'),
#  (0.33094123162156314, 'LEMMA_gang'),
#  (0.3305282677793749, 'LEMMA_Karthik'),
#  (0.33041797876402934, 'LEMMA_strangle'),
#  (0.32994072098970545, 'LEMMA_information'),
#  (0.32977046763369444, 'LEMMA_briefcase'),
#  (0.32962898214929326, 'LEMMA_Biscuit'),
#  (0.32960805199857374, 'LEMMA_inform'),
#  (0.3284750481151868, 'LEMMA_body'),
#  (0.3269183531486016, 'LEMMA_intelligence')]

# %%
for n, genre in enumerate(set(y_test)):
    print(n, genre)
# Out:
# 0 science fiction
# 1 romance
# 2 horror
# 3 adventure
# 4 action
# 5 biography
# 6 musical
# 7 drama
# 8 thriller
# 9 noir
# 10 historical
# 11 fantasy
# 12 animation
# 13 war
# 14 sport
# 15 documentary
# 16 western
# 17 comedy
# 18 family
